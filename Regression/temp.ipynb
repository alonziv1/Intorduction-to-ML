# %%
# A27:
from sklearn.metrics import mean_squared_error
import updated_data_loading.preliminary as pre
import seaborn as sns
from multiprocessing import dummy
from operator import ne
from tkinter import Y, font
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from plot3d import plot3d
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_validate
from sklearn.dummy import DummyRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, MinMaxScaler
from sklearn.linear_model import Ridge
import LinearRegressor

test_data, train_data, raw_blood = pre.updated_preprocess()

test_data.head()
# Out:
# c:\Users\alonz\Documents\GitHub\Intorduction-to-ML\Regression\updated_data_loading\prepare.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_data[symptom][index] = 1
# c:\Users\alonz\Documents\GitHub\Intorduction-to-ML\Regression\updated_data_loading\prepare.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joined_data[symptom][index] = 1
# Index(['PCR_01', 'PCR_02', 'PCR_04', 'PCR_05', 'PCR_06', 'PCR_09',
#        'sport_activity', 'sugar_levels', 'covid_score', 'spread_score', 'B',
#        'O', 'Others', 'sore_throat', 'fever', 'shortness_of_breath'],
#       dtype='object')
# Index(['PCR_01', 'PCR_02', 'PCR_04', 'PCR_05', 'PCR_06', 'PCR_09',
#        'sport_activity', 'sugar_levels', 'B', 'O', 'Others', 'sore_throat',
#        'fever', 'shortness_of_breath', 'covid_score', 'spread_score'],
#       dtype='object')
# type is <class 'pandas.core.frame.DataFrame'>
# c:\Users\alonz\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
#      B    O  Others    PCR_01    PCR_02    PCR_04    PCR_05    PCR_06  \
# 0  0.0  1.0     0.0  0.095826  0.568190  0.522635  0.124103  0.605387
# 1  0.0  0.0     1.0  0.389648  0.659301  0.291795  0.332121  0.585853
# 2  0.0  1.0     0.0  0.600324  0.702823  0.486993  0.272622  0.350089
# 3  0.0  1.0     0.0  0.747717  0.891855  0.671842  0.134612  0.638092
# 4  1.0  0.0     0.0  0.680092  0.578869  0.844232  0.287405  0.655385
#
#      PCR_09  covid_score  fever  shortness_of_breath  sore_throat  \
# 0  0.421596    11.297267    0.0                  0.0          1.0
# 1  0.495915     9.128289    0.0                  0.0          1.0
# 2  0.480815     9.669539    0.0                  0.0          1.0
# 3  0.332177    16.786373    1.0                  1.0          1.0
# 4  0.195925     1.222441    0.0                  0.0          0.0
#
#    sport_activity  spread_score  sugar_levels
# 0            0.00    166.006547      0.268908
# 1            0.25     16.894573      0.352941
# 2            0.25     21.474812      0.302521
# 3            0.00     88.705479      0.268908
# 4            0.00     21.687197      0.478992

# %%
train_data.head()
